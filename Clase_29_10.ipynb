# %% [markdown]
# <a href="https://colab.research.google.com/github/Ojagua-byte25/FUNPRO/blob/main/Clase_29_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Quiero crear un programa que me imprima letra por letra
"""
Comportamiento de un para cuando se usa con listas
for letra in lista:
  1.El para se repite la cantidad de veces delementos que tiene la lista
  2.La variable adopta el valor de cada elemento de la lista
 """
 c=1
 for letra in a:
  print(f{c}.[letra])
  c=c+1

# %%
for letra in a:
  print(f"")

# %%
a.pop("s")
a

# %%
#Hola, cómo esstas-->Hali, como ostas
a
resultado=""
for letra in range(len{a}):
 if a[letra]=="a": resultado=resultado+"i"
 elif a [letra]=="e" resultado=resultado+
 elif a [letra]=="i" resultado=resultado+
 elif a [letra]=="o" resultado=resultado+
 elif a[letra]=="u": resultad=resultado+"e"
 else: resultado=resultado+a[letra]
print(resultado)

# %%
#Por 1000xp:Cualquier mensaje codificado, se traduzca orsa or emi ñqeozi
nombre="orza or emi ñqeozi"
resultado=""
for letra in range(len{nombre}):
