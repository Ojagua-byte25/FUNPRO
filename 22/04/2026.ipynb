# %% [markdown]
# <a href="https://colab.research.google.com/github/Ojagua-byte25/FUNPRO/blob/main/22/04/2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
color_techo="ladrillo"
color_pared="blanco"
cant_ventanas=3
cant_puertas=1
cant_pisos=1
cant_baños=2
color_marco_ventanas="ocre"
decoración_flores=True
flores_decoración=[]
letrero=True
nombre_letrero="No le puse"
graffiti=True
dibujo_graffiti="diablito y un homero"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6507/2976870628.py in <cell line: 0>()
# ----> 1 color_techo=a
#       2 color_techo=a
#       3 color_techo=a
#       4 color_techo=a
#
# NameError: name 'a' is not defined

# %%
def decorado_floristeria(a,b,c,d,e,f,g,h,letreto,graffiti):
  color_techo=a
  color_techo=b
  color_techo=c
  cant_puertas=d
  cant_pisos=e
  cant_baños=f
  color_marco_ventanas=g
