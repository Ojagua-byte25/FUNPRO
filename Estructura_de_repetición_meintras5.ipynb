# %% [markdown]
# <a href="https://colab.research.google.com/github/Ojagua-byte25/FUNPRO/blob/main/Estructura_de_repetici%C3%B3n_meintras5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ESTRUCTURA DE REPETICIÓN MIENTRAS
# Es una estructura de repetición booleana empleada cuando no se sabe **cuántas veces se debe repetir la condicion**
# Comprender de:
# 1. Una condicion inicial.
# 2. Una centinela que evalua si se cumple la condición final
# 3. Un modificador de condición inicial.
#
# A diferencia de la estructura para, el modificador puede ser un contador, un acumulador o lo que sea.

# %%
ahorro=int(input("Con cuánto dinero cuento?"))
opc=input("Desea comprar algo?")
while ahorro>=0 and opc=="s":
  precio=int(input("Cuánto cuesta eso?"))
  if precio<=ahorro:
    print("Lo compro!!")
    ahorro=ahorro-precio #acumulador
  else:
    print("No me alcanza")
  opc=input("Desea comprar algo?")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-574020232.py in <cell line: 0>()
# ----> 1 ahorro=int(input("Con cuánto dinero cuento?"))
#       2 opc=input("Desea comprar algo?")
#       3 while ahorro>=0 and opc=="s":
#       4   precio=int(input("Cuánto cuesta eso?"))
#       5   if precio<=ahorro:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...
