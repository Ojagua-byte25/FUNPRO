# %% [markdown]
# <a href="https://colab.research.google.com/github/Ojagua-byte25/FUNPRO/blob/main/Trabajo_clase_22_10_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
CN=int(input("Ingrese la cantidad de números: "))
for e in range(CN):
  n=int(input(f"Ingrese el número {e+1 }: "))
  cubo=n*n*n
  print(f"El cubo del número ingresado es {cubo}")
# Out:
# Ingrese la cantidad de números: 2
# Ingrese el número 1: 2
# El cubo del número ingresado es 8
# Ingrese el número 2: 4
# El cubo del número ingresado es 64

# %%
contraseña= input("Ingrese una contraseña: ")
for e in range(contraseña):
  print("Contraseña debil.Debe tener al menos 6 caracteres")
contraseña= input("Ingrese otra contraseña: ")
print("Contraseña Aceptada")
# Out:
# Ingrese una contraseña: hola
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3486890275.py in <cell line: 0>()
#       1 Contraseña= input("Ingrese una contraseña: ")
# ----> 2 for e in range(Contraseña):
#       3   print("Contraseña debil.Debe tener al menos 6 caracteres")
#       4 contraseña= input("Ingrese otra contraseña: ")
#       5 print("Contraseña Aceptada")
#
# TypeError: 'str' object cannot be interpreted as an integer
